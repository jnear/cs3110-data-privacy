# %% [markdown]
# # CS 3110/5110: Data Privacy
# ## In-Class Exercise, week of 8/26/2024

# %%
# Load the data and libraries
import pandas as pd
import numpy as np

adult = pd.read_csv('https://github.com/jnear/cs211-data-privacy/raw/master/homework/adult_with_pii.csv')

# %%
adult
# Out:
#                     Name         DOB          SSN    Zip  Age  \
# 0       Karrie Trusslove    9/7/1967  732-14-6110  64152   39
# 1       Brandise Tripony    6/7/1988  150-19-2766  61523   50
# 2          Brenn McNeely    8/6/1991  725-59-9860  95668   38
# 3            Dorry Poter    4/6/2009  659-57-4974  25503   53
# 4            Dick Honnan   9/16/1951  220-93-3811  75387   28
# ...                  ...         ...          ...    ...  ...
# 32556       Ardyce Golby  10/29/1961  212-61-8338  41328   27
# 32557      Jean O'Connor   6/28/1952  737-32-2919  94735   40
# 32558   Reuben Skrzynski    8/9/1966  314-48-0219  49628   58
# 32559        Caye Biddle   5/19/1978  647-75-3550   8213   22
# 32560  Hortense Hardesty   5/11/2012  690-42-5638  86153   52
#
#               Workclass  fnlwgt   Education  Education-Num  \
# 0             State-gov   77516   Bachelors             13
# 1      Self-emp-not-inc   83311   Bachelors             13
# 2               Private  215646     HS-grad              9
# 3               Private  234721        11th              7
# 4               Private  338409   Bachelors             13
# ...                 ...     ...         ...            ...
# 32556           Private  257302  Assoc-acdm             12
# 32557           Private  154374     HS-grad              9
# 32558           Private  151910     HS-grad              9
# 32559           Private  201490     HS-grad              9
# 32560      Self-emp-inc  287927     HS-grad              9
#
#            Marital Status         Occupation   Relationship   Race     Sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# 1      Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2                Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3      Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4      Married-civ-spouse     Prof-specialty           Wife  Black  Female
# ...                   ...                ...            ...    ...     ...
# 32556  Married-civ-spouse       Tech-support           Wife  White  Female
# 32557  Married-civ-spouse  Machine-op-inspct        Husband  White    Male
# 32558             Widowed       Adm-clerical      Unmarried  White  Female
# 32559       Never-married       Adm-clerical      Own-child  White    Male
# 32560  Married-civ-spouse    Exec-managerial           Wife  White  Female
#
#        Capital Gain  Capital Loss  Hours per week        Country Target
# 0              2174             0              40  United-States  <=50K
# 1                 0             0              13  United-States  <=50K
# 2                 0             0              40  United-States  <=50K
# 3                 0             0              40  United-States  <=50K
# 4                 0             0              40           Cuba  <=50K
# ...             ...           ...             ...            ...    ...
# 32556             0             0              38  United-States  <=50K
# 32557             0             0              40  United-States   >50K
# 32558             0             0              40  United-States  <=50K
# 32559             0             0              20  United-States  <=50K
# 32560         15024             0              40  United-States   >50K
#
# [32561 rows x 19 columns]

# %% [markdown]
# ## Question 1
#
# Construct a de-identified version of the `adult` dataset.

# %%
adult[['Name', 'DOB']]
# Out:
#                     Name         DOB
# 0       Karrie Trusslove    9/7/1967
# 1       Brandise Tripony    6/7/1988
# 2          Brenn McNeely    8/6/1991
# 3            Dorry Poter    4/6/2009
# 4            Dick Honnan   9/16/1951
# ...                  ...         ...
# 32556       Ardyce Golby  10/29/1961
# 32557      Jean O'Connor   6/28/1952
# 32558   Reuben Skrzynski    8/9/1966
# 32559        Caye Biddle   5/19/1978
# 32560  Hortense Hardesty   5/11/2012
#
# [32561 rows x 2 columns]

# %%
def deidentify_adult():
    # goal: remove identifying information
    # process: 1. decide which columns have identifying info 2. remove them
    return adult.drop(['Name', 'DOB', 'SSN'], axis=1)

adult_deid = deidentify_adult()

# %%
assert 'Name' not in adult_deid.columns
assert 'DOB' not in adult_deid.columns
assert 'SSN' not in adult_deid.columns

# %%
adult_deid
# Out:
#          Zip  Age         Workclass  fnlwgt   Education  Education-Num  \
# 0      64152   39         State-gov   77516   Bachelors             13
# 1      61523   50  Self-emp-not-inc   83311   Bachelors             13
# 2      95668   38           Private  215646     HS-grad              9
# 3      25503   53           Private  234721        11th              7
# 4      75387   28           Private  338409   Bachelors             13
# ...      ...  ...               ...     ...         ...            ...
# 32556  41328   27           Private  257302  Assoc-acdm             12
# 32557  94735   40           Private  154374     HS-grad              9
# 32558  49628   58           Private  151910     HS-grad              9
# 32559   8213   22           Private  201490     HS-grad              9
# 32560  86153   52      Self-emp-inc  287927     HS-grad              9
#
#            Marital Status         Occupation   Relationship   Race     Sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# 1      Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2                Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3      Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4      Married-civ-spouse     Prof-specialty           Wife  Black  Female
# ...                   ...                ...            ...    ...     ...
# 32556  Married-civ-spouse       Tech-support           Wife  White  Female
# 32557  Married-civ-spouse  Machine-op-inspct        Husband  White    Male
# 32558             Widowed       Adm-clerical      Unmarried  White  Female
# 32559       Never-married       Adm-clerical      Own-child  White    Male
# 32560  Married-civ-spouse    Exec-managerial           Wife  White  Female
#
#        Capital Gain  Capital Loss  Hours per week        Country Target
# 0              2174             0              40  United-States  <=50K
# 1                 0             0              13  United-States  <=50K
# 2                 0             0              40  United-States  <=50K
# 3                 0             0              40  United-States  <=50K
# 4                 0             0              40           Cuba  <=50K
# ...             ...           ...             ...            ...    ...
# 32556             0             0              38  United-States  <=50K
# 32557             0             0              40  United-States   >50K
# 32558             0             0              40  United-States  <=50K
# 32559             0             0              20  United-States  <=50K
# 32560         15024             0              40  United-States   >50K
#
# [32561 rows x 16 columns]

# %% [markdown]
# ## Question 2
#
# What columns did you remove from the dataset to de-identify it? Why did you choose these columns? Why did you not choose the remaining columns?

# %% [markdown]
# - We removed Name, DOB, SSN because these are clearly identifying info
# - The other columns didn't seem to contain info that would uniquely identify an individual, so we didn't remove them. But it's not clear if this is really true.

# %% [markdown]
# ## Question 3
#
# Write a pandas expression to return just the row containing information about Brenn McNeely.

# %%
# Expression that returns a series
# The series has a "True" for rows that match the condition
adult['Name'] == 'Brenn McNeely'
# Out:
# 0        False
# 1        False
# 2         True
# 3        False
# 4        False
#          ...
# 32556    False
# 32557    False
# 32558    False
# 32559    False
# 32560    False
# Name: Name, Length: 32561, dtype: bool

# %%
# Expression that uses the series to index into the original dataframe
adult[adult['Name'] == 'Brenn McNeely']
# Out:
#             Name       DOB          SSN    Zip  Age Workclass  fnlwgt  \
# 2  Brenn McNeely  8/6/1991  725-59-9860  95668   38   Private  215646
#
#   Education  Education-Num Marital Status         Occupation   Relationship  \
# 2   HS-grad              9       Divorced  Handlers-cleaners  Not-in-family
#
#     Race   Sex  Capital Gain  Capital Loss  Hours per week        Country  \
# 2  White  Male             0             0              40  United-States
#
#   Target
# 2  <=50K

# %%
def get_brenns_row():
    return adult[adult['Name'] == 'Brenn McNeely']

brenns_row = get_brenns_row()[['Name', 'DOB', 'Zip', 'Age']]

# %%
assert len(brenns_row) == 1
assert brenns_row['Zip'].iloc[0] == 95668
assert brenns_row['Age'].iloc[0] == 38

# %%
brenns_row
# Out:
#             Name       DOB    Zip  Age
# 2  Brenn McNeely  8/6/1991  95668   38

# %%
adult_deid
# Out:
#          Zip  Age         Workclass  fnlwgt   Education  Education-Num  \
# 0      64152   39         State-gov   77516   Bachelors             13
# 1      61523   50  Self-emp-not-inc   83311   Bachelors             13
# 2      95668   38           Private  215646     HS-grad              9
# 3      25503   53           Private  234721        11th              7
# 4      75387   28           Private  338409   Bachelors             13
# ...      ...  ...               ...     ...         ...            ...
# 32556  41328   27           Private  257302  Assoc-acdm             12
# 32557  94735   40           Private  154374     HS-grad              9
# 32558  49628   58           Private  151910     HS-grad              9
# 32559   8213   22           Private  201490     HS-grad              9
# 32560  86153   52      Self-emp-inc  287927     HS-grad              9
#
#            Marital Status         Occupation   Relationship   Race     Sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# 1      Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2                Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3      Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4      Married-civ-spouse     Prof-specialty           Wife  Black  Female
# ...                   ...                ...            ...    ...     ...
# 32556  Married-civ-spouse       Tech-support           Wife  White  Female
# 32557  Married-civ-spouse  Machine-op-inspct        Husband  White    Male
# 32558             Widowed       Adm-clerical      Unmarried  White  Female
# 32559       Never-married       Adm-clerical      Own-child  White    Male
# 32560  Married-civ-spouse    Exec-managerial           Wife  White  Female
#
#        Capital Gain  Capital Loss  Hours per week        Country Target
# 0              2174             0              40  United-States  <=50K
# 1                 0             0              13  United-States  <=50K
# 2                 0             0              40  United-States  <=50K
# 3                 0             0              40  United-States  <=50K
# 4                 0             0              40           Cuba  <=50K
# ...             ...           ...             ...            ...    ...
# 32556             0             0              38  United-States  <=50K
# 32557             0             0              40  United-States   >50K
# 32558             0             0              40  United-States  <=50K
# 32559             0             0              20  United-States  <=50K
# 32560         15024             0              40  United-States   >50K
#
# [32561 rows x 16 columns]

# %% [markdown]
# ## Question 4
#
# Conduct a linking attack to recover Brenn's data from the `adult_deid` dataset.

# %%
def recover_brenns_row():
    # Goal: link brenns_row with adult_deid to find Brenn's row in adult_deid
    # brenns_row is the auxiliary data
    # adult_deid is the de-identified data
    # Idea: match rows based on zip code and age
    brenns_zip = 95668
    brenns_age = 38
    brenns_recovered_row = adult_deid[(adult_deid['Zip'] == brenns_zip) #&
                                      #(adult_deid['Age'] == brenns_age)
                                     ]
    return brenns_recovered_row

brenns_recovered_row = recover_brenns_row()

# %%
assert len(brenns_recovered_row) == 1
assert brenns_recovered_row['Education'].iloc[0] == 'HS-grad'
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tmp/ipykernel_1594207/461586817.py in <module>
# ----> 1 assert len(brenns_recovered_row) == 1
#       2 assert brenns_recovered_row['Education'].iloc[0] == 'HS-grad'
#
# AssertionError:

# %%
brenns_recovered_row
# Out:
#          Zip  Age Workclass  fnlwgt     Education  Education-Num  \
# 2      95668   38   Private  215646       HS-grad              9
# 23638  95668   47   Private   47247  Some-college             10
#
#            Marital Status         Occupation   Relationship   Race     Sex  \
# 2                Divorced  Handlers-cleaners  Not-in-family  White    Male
# 23638  Married-civ-spouse       Adm-clerical           Wife  White  Female
#
#        Capital Gain  Capital Loss  Hours per week        Country Target
# 2                 0             0              40  United-States  <=50K
# 23638             0             0              40  United-States  <=50K

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(adult['Age'])
# Out:
# (array([5570., 5890., 6048., 6163., 3967., 2591., 1595.,  496.,  174.,
#           67.]),
#  array([17. , 24.3, 31.6, 38.9, 46.2, 53.5, 60.8, 68.1, 75.4, 82.7, 90. ]),
#  <BarContainer object of 10 artists>)
